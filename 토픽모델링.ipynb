# %% [markdown]
# <a href="https://colab.research.google.com/github/Hongbi-Kim/Writing_lyrics/blob/master/%ED%86%A0%ED%94%BD%EB%AA%A8%EB%8D%B8%EB%A7%81.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Mecab 설치

# !pip install konlpy
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git 
# %cd Mecab-ko-for-Google-Colab/
# !bash install_mecab-ko_on_colab190912.sh
# %cd ../
# Out:
# ...
#      |████████████████████████████████| 19.4 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 448 kB 66.8 MB/s
# ...
# Cloning into 'Mecab-ko-for-Google-Colab'...
# remote: Enumerating objects: 109, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 109 (delta 7), reused 10 (delta 3), pack-reused 91
# Receiving objects: 100% (109/109), 1.27 MiB | 13.83 MiB/s, done.
# Resolving deltas: 100% (46/46), done.
# /content/Mecab-ko-for-Google-Colab
# Installing konlpy.....
# ...
# Done
# Installing mecab-0.996-ko-0.9.2.tar.gz.....
# ...
# from https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# --2022-04-19 07:47:13--  https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 104.192.141.1, 2406:da00:ff00::22e9:9f55, 2406:da00:ff00::22cd:e0db, ...
# Connecting to bitbucket.org (bitbucket.org)|104.192.141.1|:443... connected.
# ...

# %%
from konlpy.tag import Mecab
mecab = Mecab()

# %%
import pandas as pd
df = pd.read_pickle('/content/drive/MyDrive/5조_파이널PJT/코드/data/melonlyric_resetindex.pkl')
df
# Out:
#        pages   rank                                              title  \
# 0          1      1                                             사랑인가 봐
# 1          1      2                                               취중고백
# 2          1      3                                             듣고 싶을까
# 3          1      4                                          사랑은 늘 도망가
# 4          1      5                                            언제나 사랑해
# ...      ...    ...                                                ...
# 92550  26101  26146                              음주운전 하지마 (하지마송part.1)
# 92551  26101  26147  All I Want for Christmas Is You (Feat. Edward ...
# 92552  26101  26148                                  Starlight (inst.)
# 92553  26101  26149                                        사막별 (inst.)
# 92554  26101  26150                                    힘내라 친구야 (Inst.)
#
#                                                    lyric  \
# ...

# %%
results = []

for i in df['lyric']:
    fullDes = mecab.pos(i)
    words_all = []
    for j in fullDes:
        if (j[1] == 'NNG'): #| (j[1] == 'VV') | (j[1] == 'VA'):
            if j[0] not in words_all:
              words_all.append(j[0])
    results.append(words_all)

# %%
df['topic'] = results

# %%
# 명사, 형용사, 동사
df['topic']
# Out:
# 0        [하, 일, 상상, 일상, 되, 하, 모습, 보, 웃, 행동, 설레, 하, 뒤척이,...
# 1        [하, 늦, 집, 골목, 있, 놀이터, 앉, 친구, 만나, 오랜만, 술, 얼굴, 맘...
# 2        [듣, 듣, 듣, 날, 생각, 보, 목소리, 듣, 뻔하, 노랫말, 미안, 미안, 들...
# 3        [눈물, 길, 사람, 손길, 생각, 붙잡, 가슴, 떨, 아름답, 사람, 사랑, 잡,...
# 4        [손잡, 걸, 때, 보, 웃, 때, 사랑, 말, 알, 만나, 길, 입가, 미소, 흐...
#                                ...
# 92550    [하, 하, 하, 하, 하, 하, 술, 먹, 운전, 음주, 운전, 괜찮, 먹, 먹,...
# 92551    [마음, 먹, 준비, 데이트, 집, 있, 잊, 약속, 명동, 거리, 눈, 닮, 눈,...
# 92552    [떨어지, 별, 빌, 맘, 똑같, 밤, 지나, 때, 기도, 똑같, 별, 세, 새벽,...
# 92553    [무언가, 쫓, 모양, 생각, 순간, 없, 사막, 속, 별, 찾, 길, 끝, 있, ...
# 92554    [마시, 잔, 들, 친구, 사, 고생, 많, 현실, 살, 버티, 울, 울, 친구, ...
# Name: topic, Length: 92555, dtype: object

# %%
# 명사
df['topic']
# Out:
# 0        [일, 상상, 일상, 모습, 행동, 밤, 사랑, 종일, 면, 생각, 날, 행복, 정...
# 1        [집, 골목, 놀이터, 친구, 오랜만, 술, 얼굴, 맘, 사람, 생각, 대책, 진짜...
# 2             [날, 생각, 목소리, 노랫말, 미안, 후회, 미련, 진심, 말, 대답, 사랑]
# 3        [눈물, 길, 사람, 손길, 생각, 가슴, 사랑, 이별, 아이, 그리움, 바람, 옷...
# 4        [때, 사랑, 말, 길, 입가, 미소, 눈물, 밤하늘, 별, 보석, 힘, 옆, 사람...
#                                ...
# 92550    [술, 운전, 음주, 잔, 차, 대리운전, 한참, 떡, 졸음운전, 눈, 정신, 상대...
# 92551    [마음, 준비, 데이트, 집, 약속, 명동, 거리, 눈, 행복, 말, 스타일, 취향...
# 92552    [별, 맘, 밤, 때, 기도, 새벽, 하늘, 문, 귓가, 날, 속삭임, 오늘, 시간...
# 92553    [무언가, 모양, 생각, 순간, 사막, 속, 별, 길, 끝, 방향, 새벽, 밤, 앞...
# 92554    [잔, 친구, 고생, 현실, 슬픔, 걱정, 사랑, 상처, 그리움, 시간, 돈, 김밥...
# Name: topic, Length: 92555, dtype: object

# %%
df['genres_1'] = df['genres'].str.split(',',0).str[0]
df
# Out:
#        pages   rank                                              title  \
# 0          1      1                                             사랑인가 봐
# 1          1      2                                               취중고백
# 2          1      3                                             듣고 싶을까
# 3          1      4                                          사랑은 늘 도망가
# 4          1      5                                            언제나 사랑해
# ...      ...    ...                                                ...
# 92550  26101  26146                              음주운전 하지마 (하지마송part.1)
# 92551  26101  26147  All I Want for Christmas Is You (Feat. Edward ...
# 92552  26101  26148                                  Starlight (inst.)
# 92553  26101  26149                                        사막별 (inst.)
# 92554  26101  26150                                    힘내라 친구야 (Inst.)
#
#                                                    lyric  \
# ...

# %%
ballad = df[df['genres_1'] == '발라드']
dance = df[df['genres_1'] == '댄스']

# %%
dance = dance.reset_index().drop(columns = 'index')
dance
# Out:
#        pages   rank                                              title  \
# 0          1      1                                     Feel My Rhythm
# 1          1      2                                               INVU
# 2          1      3                                              RUN2U
# 3          1      4                                SMILEY (Feat. BIBI)
# 4          1      5                                             ELEVEN
# ...      ...    ...                                                ...
# 22859  26101  26146                              음주운전 하지마 (하지마송part.1)
# 22860  26101  26147  All I Want for Christmas Is You (Feat. Edward ...
# 22861  26101  26148                                  Starlight (inst.)
# 22862  26101  26149                                        사막별 (inst.)
# 22863  26101  26150                                    힘내라 친구야 (Inst.)
#
#                                                    lyric  \
# ...

# %%
result_ballad = ballad['topic']
result_dance = dance['topic']

# %%
from gensim.models.ldamodel import LdaModel
from gensim.models.callbacks import CoherenceMetric
from gensim import corpora
from gensim.models.callbacks import PerplexityMetric

import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %% [markdown]
# # 토픽모델링 - 발라드

# %%
dictionary = corpora.Dictionary(result_ballad)
# Out:
# 2022-04-19 02:31:50,103 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2022-04-19 02:31:50,399 : INFO : adding document #10000 to Dictionary(5289 unique tokens: ['날', '낼', '면', '모습', '밤']...)
# 2022-04-19 02:31:50,671 : INFO : adding document #20000 to Dictionary(7315 unique tokens: ['날', '낼', '면', '모습', '밤']...)
# 2022-04-19 02:31:50,946 : INFO : adding document #30000 to Dictionary(8744 unique tokens: ['날', '낼', '면', '모습', '밤']...)
# 2022-04-19 02:31:51,212 : INFO : adding document #40000 to Dictionary(10232 unique tokens: ['날', '낼', '면', '모습', '밤']...)
# 2022-04-19 02:31:51,490 : INFO : adding document #50000 to Dictionary(11336 unique tokens: ['날', '낼', '면', '모습', '밤']...)
# 2022-04-19 02:31:51,746 : INFO : adding document #60000 to Dictionary(12467 unique tokens: ['날', '낼', '면', '모습', '밤']...)
# 2022-04-19 02:31:52,004 : INFO : built Dictionary(13350 unique tokens: ['날', '낼', '면', '모습', '밤']...) from 69690 documents (total 2403221 corpus positions)

# %%
# 흔한 단어나 독특한 단어 제외
# 빈도 2이상인 단어와 전체의 50% 이상 차지하는 단어 필터링
dictionary.filter_extremes(no_below=2, no_above=0.5)
# Out:
# 2022-04-19 02:32:01,333 : INFO : discarding 4156 tokens: [('사랑', 44479), ('서촌', 1), ('번화가', 1), ('각잠', 1), ('감투', 1), ('단두대', 1), ('한심', 1), ('황홀경', 1), ('빙하기', 1), ('매트', 1)]...
# 2022-04-19 02:32:01,335 : INFO : keeping 9194 tokens which were in no less than 2 and no more than 34845 (=50.0%) documents
# 2022-04-19 02:32:01,344 : INFO : resulting dictionary: Dictionary(9194 unique tokens: ['날', '낼', '면', '모습', '밤']...)

# %%
corpus = [dictionary.doc2bow(text) for text in results]

# %% [markdown]
# # 모델링

# %% [markdown]
# 그중에서도 반드시 조정이 필요한 할 변수는 num_topics, chunksize, passes, interations, eval_every.\
# 각 변수를 간단하게 설명하자면,
#
# 📌 num_topics: 생성될 토픽의 개수\
# 📌 chunksize: 한번의 트레이닝에 처리될 문서의 개수\
# 📌 passes: 전체 코퍼스 트레이닝 횟수\
# 📌 interations: 문서 당 반복 횟수

# %% [markdown]
# 물론 이 파라미터를 다른 숫자로 여러번 해서 가장 정확도 높은 모델을 선택하는 것이 가장 좋습니다. 모델의 정확도는 토픽의 일관성으로도 볼 수 있을텐데, 토픽의 일관성은 Coherence를 보면 됩니다. 파라미터 eval_every=1로 설정하여, 매 pass마다 문서의 Convergence 평가하고, 대부분의 문서가 포함되는 pass를 선정할 수도 있습니다.

# %% [markdown]
# 그리하여! 저는 아래와 같이 설정해 모델링 했습니다. eval_every는 시간이 오래 걸리므로 이번에는 None으로 설정하겠습니다. alpha, eta 는 모두 auto로 해줍니다.

# %%
class gensim.models.ldamodel.LdaModel(corpus=None, num_topics=100, id2word=None, distributed=False, chunksize=2000, passes=1, update_every=1, alpha='symmetric', eta=None, decay=0.5, offset=1.0, eval_every=10, iterations=50, gamma_threshold=0.001, minimum_probability=0.01, random_state=None, ns_conf=None, minimum_phi_value=0.01, per_word_topics=False, callbacks=None, dtype=<class 'numpy.float32'>)

# %%
num_topics = 4
chunksize = 2000
passes = 20
iterations = 400
eval_every = 1

temp = dictionary[0]
id2word = dictionary.id2token

model = LdaModel(
    corpus=corpus,
    id2word=id2word,
    chunksize=chunksize,
    alpha='auto',
    eta='auto',
    iterations=iterations,
    num_topics=num_topics,
    passes=passes,
    eval_every=eval_every
)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 2022-04-19 02:39:43,766 : INFO : topic #0 (2.216): 0.074*"말" + 0.070*"날" + 0.039*"맘" + 0.037*"사람" + 0.033*"마음" + 0.031*"눈물" + 0.027*"시간" + 0.025*"기억" + 0.023*"가슴" + 0.021*"행복"
# 2022-04-19 02:39:43,768 : INFO : topic #1 (0.682): 0.051*"밤" + 0.036*"오늘" + 0.034*"하루" + 0.024*"노래" + 0.022*"때" + 0.021*"눈" + 0.020*"생각" + 0.016*"내일" + 0.014*"기분" + 0.014*"잠"
# 2022-04-19 02:39:43,770 : INFO : topic #2 (0.714): 0.047*"꿈" + 0.036*"하늘" + 0.036*"속" + 0.030*"밤" + 0.028*"길" + 0.028*"바람" + 0.026*"눈" + 0.024*"별" + 0.023*"손" + 0.022*"위"
# 2022-04-19 02:39:43,772 : INFO : topic #3 (0.305): 0.050*"친구" + 0.050*"남자" + 0.049*"여자" + 0.040*"세상" + 0.016*"인생" + 0.016*"모두" + 0.013*"나나" + 0.013*"포기" + 0.010*"미래" + 0.010*"삶"
# 2022-04-19 02:39:43,774 : INFO : topic diff=inf, rho=0.134501
# 2022-04-19 02:39:44,339 : INFO : -6.939 per-word bound, 122.7 perplexity estimate based on a held-out corpus of 2000 documents with 63833 words
# ...

# %% [markdown]
# 그리고 토픽이 어떻게 형성되었는지, Coherence는 적당하게 나왔는지 확인해보겠습니다. 하나의 토픽 당 20개의 단어가 기본으로 보여지지만, 이는 변경 가능합니다.

# %%
top_topics = model.top_topics(corpus, topn = 30) #, num_words=20)

# Average topic coherence is the sum of topic coherences of all topics, divided by the number of topics.
avg_topic_coherence = sum([t[1] for t in top_topics]) / num_topics
print('Average topic coherence: %.4f.' % avg_topic_coherence)

from pprint import pprint
pprint(top_topics)
# Out:
# 2022-04-19 02:52:07,908 : INFO : CorpusAccumulator accumulated stats from 1000 documents
# 2022-04-19 02:52:07,919 : INFO : CorpusAccumulator accumulated stats from 2000 documents
# 2022-04-19 02:52:07,934 : INFO : CorpusAccumulator accumulated stats from 3000 documents
# 2022-04-19 02:52:07,946 : INFO : CorpusAccumulator accumulated stats from 4000 documents
# 2022-04-19 02:52:07,965 : INFO : CorpusAccumulator accumulated stats from 5000 documents
# 2022-04-19 02:52:07,978 : INFO : CorpusAccumulator accumulated stats from 6000 documents
# 2022-04-19 02:52:07,992 : INFO : CorpusAccumulator accumulated stats from 7000 documents
# 2022-04-19 02:52:08,004 : INFO : CorpusAccumulator accumulated stats from 8000 documents
# 2022-04-19 02:52:08,015 : INFO : CorpusAccumulator accumulated stats from 9000 documents
# 2022-04-19 02:52:08,030 : INFO : CorpusAccumulator accumulated stats from 10000 documents
# ...

# %%
word_list = []

for j in range(4):
  word = []
  for i in range(30):
    word.append(top_topics[j][0][i][1])
  word_list.append(word)
word_list
# Out:
# [['날',
#   '말',
#   '맘',
#   '마음',
#   '시간',
#   '사람',
#   '생각',
#   '가슴',
#   '모습',
#   '눈물',
#   '속',
#   '기억',
#   '곁',
#   '행복',
#   '때',
#   '눈',
#   '순간',
#   '끝',
#   '이상',
#   '추억',
#   '일',
#   '세상',
#   '이별',
#   '바보',
#   '하루',
#   '혼자',
#   '손',
#   '눈빛',
#   '앞',
#   '미안'],
#  ['꿈',
#   '속',
#   '하늘',
#   '눈',
#   '밤',
#   '위',
#   '손',
#   '세상',
#   '빛',
#   '바람',
#   '길',
#   '별',
#   '끝',
#   '춤',
#   '향기',
#   '순간',
#   '마음',
#   '어둠',
#   '곳',
#   '소리',
#   '햇살',
#   '꽃',
#   '비',
#   '거리',
#   '아래',
#   '태양',
#   '바다',
#   '여름',
#   '안',
#   '달'],
#  ['밤',
#   '오늘',
#   '눈',
#   '때',
#   '기분',
#   '노래',
#   '하루',
#   '생각',
#   '머리',
#   '맘',
#   '축하',
#   '내일',
#   '사이',
#   '생일',
#   '심장',
#   '느낌',
#   '몸',
#   '전화',
#   '집',
#   '잠',
#   '음악',
#   '상상',
#   '고민',
#   '시작',
#   '앞',
#   '종일',
#   '아침',
#   '입술',
#   '입',
#   '얼굴'],
#  ['여자',
#   '남자',
#   '친구',
#   '세상',
#   '모두',
#   '나나',
#   '인생',
#   '포기',
#   '오빠',
#   '미래',
#   '애',
#   '필요',
#   '돈',
# ...

# %%
ballad['topic']
# Out:
# 0        [일, 상상, 일상, 모습, 행동, 밤, 사랑, 종일, 면, 사랑, 일, 생각, 날...
# 1        [집, 골목, 놀이터, 친구, 오랜만, 술, 얼굴, 맘, 사람, 생각, 대책, 진짜...
# 2        [날, 생각, 목소리, 노랫말, 미안, 미안, 후회, 미련, 진심, 날, 생각, 목...
# 3        [눈물, 길, 사람, 손길, 생각, 가슴, 사람, 사랑, 이별, 사람, 사랑, 아이...
# 4        [때, 때, 사랑, 말, 길, 입가, 미소, 사랑, 사랑, 눈물, 사랑, 밤하늘, ...
#                                ...
# 69685    [파도, 맘, 바람, 맘, 연기, 사랑, 문신, 한숨, 땅, 가슴속, 먼지, 하루,...
# 69686    [때, 남자, 을, 뒤, 시선, 매력, 눈, 길, 남자, 때, 부담, 여자, 애, ...
# 69687    [생각, 사랑, 모습, 모습, 바보, 눈가, 비, 포기, 자리, 향기, 입술, 바보...
# 69688    [손, 어깨, 눈, 도착, 손, 어깨, 창문, 도착, 사랑, 말, 사치, 생각, 눈...
# 69689    [길, 건너편, 커플, 모습, 벚꽃, 길, 주머니, 속, 혼자, 손, 버스, 창가,...
# Name: topic, Length: 69690, dtype: object

# %%
ballad['topic_name'] = '기타'

# %%
'일' in word_list[0]
# Out:
# True

# %%
for word in word_list:
  for n in range(len(ballad)):
    for topics in ballad['topic']:
      for j in topics:
        if j in word:
          ballad['topic_name'][n] = word[0]

# %%
ballad['topic_name']

# %% [markdown]
# # 시각화

# %%
# !pip install pyLDAvis
# Out:
# ...
#      |████████████████████████████████| 1.7 MB 5.0 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# ...
#   Created wheel for pyLDAvis: filename=pyLDAvis-3.3.1-py2.py3-none-any.whl size=136898 sha256=b29ca49bdf0a1de482aa5628f36463b8246fc1a09a0f174621cbf0d591e78491
#   Stored in directory: /root/.cache/pip/wheels/c9/21/f6/17bcf2667e8a68532ba2fbf6d5c72fdf4c7f7d9abfa4852d2f
# Successfully built pyLDAvis
# ...

# %%
import pickle
import pyLDAvis.gensim_models as gensimvis
import pyLDAvis
from gensim.models.coherencemodel import CoherenceModel
import matplotlib.pyplot as plt
# Out:
# 2022-04-19 04:09:59,771 : INFO : Generating grammar tables from /usr/lib/python3.7/lib2to3/Grammar.txt
# 2022-04-19 04:10:00,741 : INFO : Generating grammar tables from /usr/lib/python3.7/lib2to3/PatternGrammar.txt
# /usr/local/lib/python3.7/dist-packages/past/types/oldstr.py:5: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Iterable

# %%
lda_visualization = gensimvis.prepare(model, corpus, dictionary, sort_topics=False)
pyLDAvis.save_html(lda_visualization, '/content/drive/MyDrive/Colab Notebooks/writing_lyrics/topic_ballad.html')
# Out:
# /usr/local/lib/python3.7/dist-packages/pyLDAvis/_prepare.py:247: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   by='saliency', ascending=False).head(R).drop('saliency', 1)

# %% [markdown]
# # 토픽모델링 - 댄스

# %%
dictionary_dance = corpora.Dictionary(result_dance)
# Out:
# 2022-04-19 09:16:01,626 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2022-04-19 09:16:01,930 : INFO : adding document #10000 to Dictionary(10220 unique tokens: ['경계', '곳', '꽃가루', '꿈', '끝']...)
# 2022-04-19 09:16:02,207 : INFO : adding document #20000 to Dictionary(13705 unique tokens: ['경계', '곳', '꽃가루', '꿈', '끝']...)
# 2022-04-19 09:16:02,285 : INFO : built Dictionary(14536 unique tokens: ['경계', '곳', '꽃가루', '꿈', '끝']...) from 22864 documents (total 556721 corpus positions)

# %%
# 흔한 단어나 독특한 단어 제외
# 빈도 2이상인 단어와 전체의 50% 이상 차지하는 단어 필터링
dictionary_dance.filter_extremes(no_below=2, no_above=0.7)
# Out:
# 2022-04-19 09:16:03,946 : INFO : discarding 4698 tokens: [('장땡', 1), ('공해', 1), ('보물선', 1), ('소싯적', 1), ('분리', 1), ('구축', 1), ('생력', 1), ('전야제', 1), ('명복', 1), ('물마루', 1)]...
# 2022-04-19 09:16:03,947 : INFO : keeping 9838 tokens which were in no less than 2 and no more than 16004 (=70.0%) documents
# 2022-04-19 09:16:03,956 : INFO : resulting dictionary: Dictionary(9838 unique tokens: ['경계', '곳', '꽃가루', '꿈', '끝']...)

# %%
corpus_dance = [dictionary_dance.doc2bow(text) for text in results]

# %% [markdown]
# # 모델링

# %% [markdown]
# 그중에서도 반드시 조정이 필요한 할 변수는 num_topics, chunksize, passes, interations, eval_every.\
# 각 변수를 간단하게 설명하자면,
#
# 📌 num_topics: 생성될 토픽의 개수\
# 📌 chunksize: 한번의 트레이닝에 처리될 문서의 개수\
# 📌 passes: 전체 코퍼스 트레이닝 횟수\
# 📌 interations: 문서 당 반복 횟수

# %% [markdown]
# 물론 이 파라미터를 다른 숫자로 여러번 해서 가장 정확도 높은 모델을 선택하는 것이 가장 좋습니다. 모델의 정확도는 토픽의 일관성으로도 볼 수 있을텐데, 토픽의 일관성은 Coherence를 보면 됩니다. 파라미터 eval_every=1로 설정하여, 매 pass마다 문서의 Convergence 평가하고, 대부분의 문서가 포함되는 pass를 선정할 수도 있습니다.

# %% [markdown]
# 그리하여! 저는 아래와 같이 설정해 모델링 했습니다. eval_every는 시간이 오래 걸리므로 이번에는 None으로 설정하겠습니다. alpha, eta 는 모두 auto로 해줍니다.

# %%
class gensim.models.ldamodel.LdaModel(corpus=None, num_topics=100, id2word=None, distributed=False, chunksize=2000, passes=1, update_every=1, alpha='symmetric', eta=None, decay=0.5, offset=1.0, eval_every=10, iterations=50, gamma_threshold=0.001, minimum_probability=0.01, random_state=None, ns_conf=None, minimum_phi_value=0.01, per_word_topics=False, callbacks=None, dtype=<class 'numpy.float32'>)

# %%
num_topics = 4
chunksize = 2000
passes = 20
iterations = 400
eval_every = 1

temp_dance = dictionary_dance[0]
id2word_dance = dictionary_dance.id2token

model_dance = LdaModel(
    corpus=corpus_dance,
    id2word=id2word_dance,
    chunksize=chunksize,
    alpha='auto',
    eta='auto',
    iterations=iterations,
    num_topics=num_topics,
    passes=passes,
    eval_every=eval_every
)
# Out:
# Streaming output truncated to the last 5000 lines.
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
# ...

# %% [markdown]
# 그리고 토픽이 어떻게 형성되었는지, Coherence는 적당하게 나왔는지 확인해보겠습니다. 하나의 토픽 당 20개의 단어가 기본으로 보여지지만, 이는 변경 가능합니다.

# %%
top_topics_dance = model_dance.top_topics(corpus_dance, topn = 30) #, num_words=20)

# Average topic coherence is the sum of topic coherences of all topics, divided by the number of topics.
avg_topic_coherence_dance = sum([t[1] for t in top_topics_dance]) / num_topics
print('Average topic coherence: %.4f.' % avg_topic_coherence_dance)

from pprint import pprint
pprint(top_topics_dance)
# Out:
# 2022-04-19 08:09:25,516 : INFO : CorpusAccumulator accumulated stats from 1000 documents
# 2022-04-19 08:09:25,529 : INFO : CorpusAccumulator accumulated stats from 2000 documents
# 2022-04-19 08:09:25,540 : INFO : CorpusAccumulator accumulated stats from 3000 documents
# 2022-04-19 08:09:25,552 : INFO : CorpusAccumulator accumulated stats from 4000 documents
# 2022-04-19 08:09:25,570 : INFO : CorpusAccumulator accumulated stats from 5000 documents
# 2022-04-19 08:09:25,580 : INFO : CorpusAccumulator accumulated stats from 6000 documents
# 2022-04-19 08:09:25,593 : INFO : CorpusAccumulator accumulated stats from 7000 documents
# 2022-04-19 08:09:25,603 : INFO : CorpusAccumulator accumulated stats from 8000 documents
# 2022-04-19 08:09:25,616 : INFO : CorpusAccumulator accumulated stats from 9000 documents
# 2022-04-19 08:09:25,627 : INFO : CorpusAccumulator accumulated stats from 10000 documents
# ...

# %%
word_list = []

for j in range(4):
  word = []
  for i in range(30):
    word.append(top_topics_dance[j][0][i][1])
  word_list.append(word)
word_list
# 말, 밤, 남자, 돈
# Out:
# [['말',
#   '맘',
#   '마음',
#   '시간',
#   '생각',
#   '속',
#   '눈',
#   '사람',
#   '때',
#   '모습',
#   '가슴',
#   '눈물',
#   '행복',
#   '순간',
#   '세상',
#   '기억',
#   '끝',
#   '곁',
#   '하루',
#   '오늘',
#   '일',
#   '손',
#   '추억',
#   '눈빛',
#   '이상',
#   '앞',
#   '혼자',
#   '꿈',
#   '미소',
#   '시작'],
#  ['밤',
#   '하늘',
#   '위',
#   '꿈',
#   '바람',
#   '빛',
#   '속',
#   '소리',
#   '별',
#   '손',
#   '눈',
#   '노래',
#   '향기',
#   '길',
#   '거리',
#   '어둠',
#   '햇살',
#   '아침',
#   '태양',
#   '아래',
#   '세상',
#   '비',
#   '구름',
#   '꽃',
#   '바다',
#   '곳',
#   '달',
#   '파도',
#   '해',
#   '춤'],
#  ['남자',
#   '여자',
#   '친구',
#   '기분',
#   '머리',
#   '필요',
#   '심장',
#   '몸',
#   '느낌',
#   '시선',
#   '집',
#   '전화',
#   '상상',
#   '고민',
#   '사이',
#   '입',
#   '앞',
#   '음악',
#   '감정',
#   '준비',
#   '애',
#   '원',
#   '눈치',
#   '완벽',
#   '술',
#   '매력',
#   '영화',
#   '인생',
#   '시작',
#   '때'],
#  ['돈',
#   '게임',
#   '인생',
#   '거부',
#   '감각',
#   '몸매',
#   '세계',
#   '틀',
#   '열정',
#   '시험',
#   '멋',
#   '허리',
#   '실패',
# ...

# %%
dance['topic']
# Out:
# 0        [무도회, 소란, 등장, 인사, 파격, 지금, 시작, 꽃가루, 폭죽, 오만, 편견,...
# 1         [시작, 순간, 날, 아이, 기대, 손길, 때, 기분, 처음, 상처, 전, 온기, 맘]
# 2        [기대, 겉, 걱정, 말, 막, 헛소리, 이해, 참견, 가짜, 사랑, 선, 물불, ...
# 3        [어린아이, 말, 하늘, 맘, 아픔, 슬픔, 외로움, 눈물, 차오, 안녕, 비웃, ...
# 4        [눈빛, 무표정, 얼굴, 눈동자, 안, 감정, 입술, 이름, 맘, 꿈, 방, 춤, ...
#                                ...
# 22859    [술, 운전, 음주, 잔, 차, 대리운전, 한참, 떡, 졸음운전, 눈, 정신, 상대...
# 22860    [마음, 준비, 데이트, 집, 약속, 명동, 거리, 눈, 행복, 말, 스타일, 취향...
# 22861    [별, 맘, 밤, 때, 기도, 새벽, 하늘, 문, 귓가, 날, 속삭임, 오늘, 시간...
# 22862    [무언가, 모양, 생각, 순간, 사막, 속, 별, 길, 끝, 방향, 새벽, 밤, 앞...
# 22863    [잔, 친구, 고생, 현실, 슬픔, 걱정, 사랑, 상처, 그리움, 시간, 돈, 김밥...
# Name: topic, Length: 22864, dtype: object

# %%
dance['topic_name'] = '기타'

# %%
'일' in word_list[0]
# Out:
# True

# %%
for word in word_list:
  for n in range(len(dance)):
    for topics in dance['topic']:
      for j in topics:
        if j in word:
          dance['topic_name'][n] = word[0]

# %%
for word in word_list:
  for n in range(len(dance)):
    for j in dance['topic'][n]:
      if j in word:
        dance['topic_name'][n] = word[0]

# %%
for i in range(34):
    sales = train[train.date_block_num == i]
    matrix.append( np.array(list( product( [i], sales.shop_id.unique(), sales.item_id.unique() ) ), dtype = np.int16) )

# %%
dance['topic_name'].unique() # 말, 밤, 남자, 돈
# Out:
# array(['남자', '돈', '밤', '기타', '말'], dtype=object)

# %%
a1 = dance[dance['topic_name'] == '말']
a2 = dance[dance['topic_name'] == '밤']
a3 = dance[dance['topic_name'] == '남자']
a4 = dance[dance['topic_name'] == '돈']
a5 = dance[dance['topic_name'] == '기타']
len(a1), len(a2), len(a3), len(a4), len(a5)
# Out:
# (475, 2639, 13905, 5714, 131)

# %% [markdown]
# # 시각화

# %%
# !pip install pyLDAvis
# Out:
# ...
#      |████████████████████████████████| 1.7 MB 5.0 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# ...
#   Created wheel for pyLDAvis: filename=pyLDAvis-3.3.1-py2.py3-none-any.whl size=136898 sha256=ae4dde66bebf3fb722057113b697d73cd14d1b324f995bf6938d25b6533b3c61
#   Stored in directory: /root/.cache/pip/wheels/c9/21/f6/17bcf2667e8a68532ba2fbf6d5c72fdf4c7f7d9abfa4852d2f
# Successfully built pyLDAvis
# ...

# %%
import pickle
import pyLDAvis.gensim_models as gensimvis
import pyLDAvis
from gensim.models.coherencemodel import CoherenceModel
import matplotlib.pyplot as plt
# Out:
# 2022-04-19 08:09:56,418 : INFO : Generating grammar tables from /usr/lib/python3.7/lib2to3/Grammar.txt
# 2022-04-19 08:09:56,439 : INFO : Generating grammar tables from /usr/lib/python3.7/lib2to3/PatternGrammar.txt
# /usr/local/lib/python3.7/dist-packages/past/types/oldstr.py:5: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Iterable

# %%
lda_visualization_dance = gensimvis.prepare(model_dance, corpus_dance, dictionary_dance, sort_topics=False)
pyLDAvis.save_html(lda_visualization_dance, '/content/drive/MyDrive/Colab Notebooks/writing_lyrics/topic_dance.html')
# Out:
# /usr/local/lib/python3.7/dist-packages/pyLDAvis/_prepare.py:247: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   by='saliency', ascending=False).head(R).drop('saliency', 1)
